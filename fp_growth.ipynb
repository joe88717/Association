# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

# %%
dataset = [['a', 'd', 'e'],
           ['a', 'b', 'c', 'e'],
           ['a', 'b', 'd', 'e'],
           ['a', 'c', 'd', 'e'],
           ['b', 'c', 'e'],
           ['b', 'd', 'e'],
           ['c', 'd'],
           ['a', 'b', 'c'],
           ['a', 'd', 'e'],
           ['a', 'b', 'e']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
pd.set_option('display.max_rows',None)
# min_support 關聯性
frequent_itemsets = fpgrowth(df, min_support=0.1, use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support      itemsets
# 0       0.8           (e)
# 1       0.7           (a)
# 2       0.6           (d)
# 3       0.6           (b)
# 4       0.5           (c)
# 5       0.6        (e, a)
# 6       0.5        (e, d)
# 7       0.4        (a, d)
# 8       0.4     (e, a, d)
# 9       0.5        (e, b)
# 10      0.4        (a, b)
# 11      0.2        (d, b)
# 12      0.3     (e, a, b)
# 13      0.2     (d, e, b)
# 14      0.1     (d, a, b)
# 15      0.1  (d, e, a, b)
# 16      0.3        (c, b)
# 17      0.3        (c, a)
# 18      0.3        (e, c)
# 19      0.2        (c, d)
# 20      0.2     (c, a, b)
# 21      0.2     (c, e, a)
# 22      0.2     (e, c, b)
# 23      0.1  (c, e, a, b)
# 24      0.1     (e, c, d)
# 25      0.1     (c, a, d)
# 26      0.1  (c, e, a, d)

# %%
from mlxtend.frequent_patterns import association_rules

associatio_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
# Out:
#     antecedents consequents  antecedent support  consequent support  support  \
# 0           (e)         (a)                 0.8                 0.7      0.6
# 1           (a)         (e)                 0.7                 0.8      0.6
# 2           (e)         (d)                 0.8                 0.6      0.5
# 3           (d)         (e)                 0.6                 0.8      0.5
# 4           (a)         (d)                 0.7                 0.6      0.4
# 5           (d)         (a)                 0.6                 0.7      0.4
# 6        (e, a)         (d)                 0.6                 0.6      0.4
# 7        (e, d)         (a)                 0.5                 0.7      0.4
# 8        (a, d)         (e)                 0.4                 0.8      0.4
# 9           (e)      (a, d)                 0.8                 0.4      0.4
# 10          (a)      (e, d)                 0.7                 0.5      0.4
# 11          (d)      (e, a)                 0.6                 0.6      0.4
# 12          (e)         (b)                 0.8                 0.6      0.5
# 13          (b)         (e)                 0.6                 0.8      0.5
# 14          (a)         (b)                 0.7                 0.6      0.4
# 15          (b)         (a)                 0.6                 0.7      0.4
# 16          (d)         (b)                 0.6                 0.6      0.2
# 17          (b)         (d)                 0.6                 0.6      0.2
# 18       (e, a)         (b)                 0.6                 0.6      0.3
# 19       (e, b)         (a)                 0.5                 0.7      0.3
# 20       (a, b)         (e)                 0.4                 0.8      0.3
# 21          (e)      (a, b)                 0.8                 0.4      0.3
# 22          (a)      (e, b)                 0.7                 0.5      0.3
# 23          (b)      (e, a)                 0.6                 0.6      0.3
# 24       (e, d)         (b)                 0.5                 0.6      0.2
# 25       (d, b)         (e)                 0.2                 0.8      0.2
# 26       (e, b)         (d)                 0.5                 0.6      0.2
# 27          (d)      (e, b)                 0.6                 0.5      0.2
# 28          (e)      (d, b)                 0.8                 0.2      0.2
# 29          (b)      (e, d)                 0.6                 0.5      0.2
# 30       (a, d)         (b)                 0.4                 0.6      0.1
# 31       (d, b)         (a)                 0.2                 0.7      0.1
# 32       (a, b)         (d)                 0.4                 0.6      0.1
# 33          (d)      (a, b)                 0.6                 0.4      0.1
# 34          (a)      (d, b)                 0.7                 0.2      0.1
# 35          (b)      (a, d)                 0.6                 0.4      0.1
# 36    (e, a, d)         (b)                 0.4                 0.6      0.1
# 37    (e, d, b)         (a)                 0.2                 0.7      0.1
# 38    (a, d, b)         (e)                 0.1                 0.8      0.1
# 39    (e, a, b)         (d)                 0.3                 0.6      0.1
# 40       (e, d)      (a, b)                 0.5                 0.4      0.1
# 41       (a, d)      (e, b)                 0.4                 0.5      0.1
# 42       (d, b)      (e, a)                 0.2                 0.6      0.1
# 43       (e, a)      (d, b)                 0.6                 0.2      0.1
# 44       (e, b)      (a, d)                 0.5                 0.4      0.1
# 45       (a, b)      (e, d)                 0.4                 0.5      0.1
# 46          (d)   (e, a, b)                 0.6                 0.3      0.1
# 47          (e)   (a, d, b)                 0.8                 0.1      0.1
# 48          (a)   (e, d, b)                 0.7                 0.2      0.1
# 49          (b)   (e, a, d)                 0.6                 0.4      0.1
# 50          (c)         (b)                 0.5                 0.6      0.3
# 51          (b)         (c)                 0.6                 0.5      0.3
# 52          (c)         (a)                 0.5                 0.7      0.3
# 53          (a)         (c)                 0.7                 0.5      0.3
# 54          (e)         (c)                 0.8                 0.5      0.3
# 55          (c)         (e)                 0.5                 0.8      0.3
# 56          (c)         (d)                 0.5                 0.6      0.2
# 57          (d)         (c)                 0.6                 0.5      0.2
# 58       (c, a)         (b)                 0.3                 0.6      0.2
# 59       (c, b)         (a)                 0.3                 0.7      0.2
# 60       (a, b)         (c)                 0.4                 0.5      0.2
# 61          (c)      (a, b)                 0.5                 0.4      0.2
# 62          (a)      (c, b)                 0.7                 0.3      0.2
# 63          (b)      (c, a)                 0.6                 0.3      0.2
# 64       (e, c)         (a)                 0.3                 0.7      0.2
# 65       (c, a)         (e)                 0.3                 0.8      0.2
# 66       (e, a)         (c)                 0.6                 0.5      0.2
# 67          (c)      (e, a)                 0.5                 0.6      0.2
# 68          (e)      (c, a)                 0.8                 0.3      0.2
# 69          (a)      (e, c)                 0.7                 0.3      0.2
# 70       (e, c)         (b)                 0.3                 0.6      0.2
# 71       (e, b)         (c)                 0.5                 0.5      0.2
# 72       (c, b)         (e)                 0.3                 0.8      0.2
# 73          (e)      (c, b)                 0.8                 0.3      0.2
# 74          (c)      (e, b)                 0.5                 0.5      0.2
# 75          (b)      (e, c)                 0.6                 0.3      0.2
# 76    (e, c, a)         (b)                 0.2                 0.6      0.1
# 77    (e, c, b)         (a)                 0.2                 0.7      0.1
# 78    (c, a, b)         (e)                 0.2                 0.8      0.1
# 79    (e, a, b)         (c)                 0.3                 0.5      0.1
# 80       (e, c)      (a, b)                 0.3                 0.4      0.1
# 81       (c, a)      (e, b)                 0.3                 0.5      0.1
# 82       (c, b)      (e, a)                 0.3                 0.6      0.1
# 83       (e, a)      (c, b)                 0.6                 0.3      0.1
# 84       (e, b)      (c, a)                 0.5                 0.3      0.1
# 85       (a, b)      (e, c)                 0.4                 0.3      0.1
# 86          (c)   (e, a, b)                 0.5                 0.3      0.1
# 87          (e)   (c, a, b)                 0.8                 0.2      0.1
# 88          (a)   (e, c, b)                 0.7                 0.2      0.1
# 89          (b)   (e, c, a)                 0.6                 0.2      0.1
# 90       (e, c)         (d)                 0.3                 0.6      0.1
# 91       (e, d)         (c)                 0.5                 0.5      0.1
# 92       (c, d)         (e)                 0.2                 0.8      0.1
# 93          (e)      (c, d)                 0.8                 0.2      0.1
# 94          (c)      (e, d)                 0.5                 0.5      0.1
# 95          (d)      (e, c)                 0.6                 0.3      0.1
# 96       (c, a)         (d)                 0.3                 0.6      0.1
# 97       (c, d)         (a)                 0.2                 0.7      0.1
# 98       (a, d)         (c)                 0.4                 0.5      0.1
# 99          (c)      (a, d)                 0.5                 0.4      0.1
# 100         (a)      (c, d)                 0.7                 0.2      0.1
# 101         (d)      (c, a)                 0.6                 0.3      0.1
# 102   (e, c, a)         (d)                 0.2                 0.6      0.1
# 103   (e, c, d)         (a)                 0.1                 0.7      0.1
# 104   (d, c, a)         (e)                 0.1                 0.8      0.1
# 105   (e, a, d)         (c)                 0.4                 0.5      0.1
# 106      (e, c)      (a, d)                 0.3                 0.4      0.1
# 107      (c, a)      (e, d)                 0.3                 0.5      0.1
# 108      (c, d)      (e, a)                 0.2                 0.6      0.1
# 109      (e, a)      (c, d)                 0.6                 0.2      0.1
# 110      (e, d)      (c, a)                 0.5                 0.3      0.1
# 111      (a, d)      (e, c)                 0.4                 0.3      0.1
# 112         (c)   (e, a, d)                 0.5                 0.4      0.1
# 113         (e)   (d, c, a)                 0.8                 0.1      0.1
# 114         (a)   (e, c, d)                 0.7                 0.1      0.1
# 115         (d)   (e, c, a)                 0.6                 0.2      0.1
#
#      confidence      lift  leverage  conviction
# 0      0.750000  1.071429      0.04    1.200000
# 1      0.857143  1.071429      0.04    1.400000
# 2      0.625000  1.041667      0.02    1.066667
# 3      0.833333  1.041667      0.02    1.200000
# 4      0.571429  0.952381     -0.02    0.933333
# 5      0.666667  0.952381     -0.02    0.900000
# 6      0.666667  1.111111      0.04    1.200000
# 7      0.800000  1.142857      0.05    1.500000
# 8      1.000000  1.250000      0.08         inf
# 9      0.500000  1.250000      0.08    1.200000
# 10     0.571429  1.142857      0.05    1.166667
# 11     0.666667  1.111111      0.04    1.200000
# 12     0.625000  1.041667      0.02    1.066667
# 13     0.833333  1.041667      0.02    1.200000
# 14     0.571429  0.952381     -0.02    0.933333
# 15     0.666667  0.952381     -0.02    0.900000
# 16     0.333333  0.555556     -0.16    0.600000
# 17     0.333333  0.555556     -0.16    0.600000
# 18     0.500000  0.833333     -0.06    0.800000
# 19     0.600000  0.857143     -0.05    0.750000
# 20     0.750000  0.937500     -0.02    0.800000
# 21     0.375000  0.937500     -0.02    0.960000
# 22     0.428571  0.857143     -0.05    0.875000
# 23     0.500000  0.833333     -0.06    0.800000
# 24     0.400000  0.666667     -0.10    0.666667
# 25     1.000000  1.250000      0.04         inf
# 26     0.400000  0.666667     -0.10    0.666667
# 27     0.333333  0.666667     -0.10    0.750000
# 28     0.250000  1.250000      0.04    1.066667
# 29     0.333333  0.666667     -0.10    0.750000
# 30     0.250000  0.416667     -0.14    0.533333
# 31     0.500000  0.714286     -0.04    0.600000
# 32     0.250000  0.416667     -0.14    0.533333
# 33     0.166667  0.416667     -0.14    0.720000
# 34     0.142857  0.714286     -0.04    0.933333
# 35     0.166667  0.416667     -0.14    0.720000
# 36     0.250000  0.416667     -0.14    0.533333
# 37     0.500000  0.714286     -0.04    0.600000
# 38     1.000000  1.250000      0.02         inf
# 39     0.333333  0.555556     -0.08    0.600000
# 40     0.200000  0.500000     -0.10    0.750000
# 41     0.250000  0.500000     -0.10    0.666667
# 42     0.500000  0.833333     -0.02    0.800000
# 43     0.166667  0.833333     -0.02    0.960000
# 44     0.200000  0.500000     -0.10    0.750000
# 45     0.250000  0.500000     -0.10    0.666667
# 46     0.166667  0.555556     -0.08    0.840000
# 47     0.125000  1.250000      0.02    1.028571
# 48     0.142857  0.714286     -0.04    0.933333
# 49     0.166667  0.416667     -0.14    0.720000
# 50     0.600000  1.000000      0.00    1.000000
# 51     0.500000  1.000000      0.00    1.000000
# 52     0.600000  0.857143     -0.05    0.750000
# 53     0.428571  0.857143     -0.05    0.875000
# 54     0.375000  0.750000     -0.10    0.800000
# 55     0.600000  0.750000     -0.10    0.500000
# 56     0.400000  0.666667     -0.10    0.666667
# 57     0.333333  0.666667     -0.10    0.750000
# 58     0.666667  1.111111      0.02    1.200000
# 59     0.666667  0.952381     -0.01    0.900000
# 60     0.500000  1.000000      0.00    1.000000
# 61     0.400000  1.000000      0.00    1.000000
# 62     0.285714  0.952381     -0.01    0.980000
# 63     0.333333  1.111111      0.02    1.050000
# 64     0.666667  0.952381     -0.01    0.900000
# 65     0.666667  0.833333     -0.04    0.600000
# 66     0.333333  0.666667     -0.10    0.750000
# 67     0.400000  0.666667     -0.10    0.666667
# 68     0.250000  0.833333     -0.04    0.933333
# 69     0.285714  0.952381     -0.01    0.980000
# 70     0.666667  1.111111      0.02    1.200000
# 71     0.400000  0.800000     -0.05    0.833333
# 72     0.666667  0.833333     -0.04    0.600000
# 73     0.250000  0.833333     -0.04    0.933333
# 74     0.400000  0.800000     -0.05    0.833333
# 75     0.333333  1.111111      0.02    1.050000
# 76     0.500000  0.833333     -0.02    0.800000
# 77     0.500000  0.714286     -0.04    0.600000
# 78     0.500000  0.625000     -0.06    0.400000
# 79     0.333333  0.666667     -0.05    0.750000
# 80     0.333333  0.833333     -0.02    0.900000
# 81     0.333333  0.666667     -0.05    0.750000
# 82     0.333333  0.555556     -0.08    0.600000
# 83     0.166667  0.555556     -0.08    0.840000
# 84     0.200000  0.666667     -0.05    0.875000
# 85     0.250000  0.833333     -0.02    0.933333
# 86     0.200000  0.666667     -0.05    0.875000
# 87     0.125000  0.625000     -0.06    0.914286
# 88     0.142857  0.714286     -0.04    0.933333
# 89     0.166667  0.833333     -0.02    0.960000
# 90     0.333333  0.555556     -0.08    0.600000
# 91     0.200000  0.400000     -0.15    0.625000
# 92     0.500000  0.625000     -0.06    0.400000
# 93     0.125000  0.625000     -0.06    0.914286
# 94     0.200000  0.400000     -0.15    0.625000
# 95     0.166667  0.555556     -0.08    0.840000
# 96     0.333333  0.555556     -0.08    0.600000
# 97     0.500000  0.714286     -0.04    0.600000
# 98     0.250000  0.500000     -0.10    0.666667
# 99     0.200000  0.500000     -0.10    0.750000
# 100    0.142857  0.714286     -0.04    0.933333
# 101    0.166667  0.555556     -0.08    0.840000
# 102    0.500000  0.833333     -0.02    0.800000
# 103    1.000000  1.428571      0.03         inf
# 104    1.000000  1.250000      0.02         inf
# 105    0.250000  0.500000     -0.10    0.666667
# 106    0.333333  0.833333     -0.02    0.900000
# 107    0.333333  0.666667     -0.05    0.750000
# 108    0.500000  0.833333     -0.02    0.800000
# 109    0.166667  0.833333     -0.02    0.960000
# 110    0.200000  0.666667     -0.05    0.875000
# 111    0.250000  0.833333     -0.02    0.933333
# 112    0.200000  0.500000     -0.10    0.750000
# 113    0.125000  1.250000      0.02    1.028571
# 114    0.142857  1.428571      0.03    1.050000
# 115    0.166667  0.833333     -0.02    0.960000
